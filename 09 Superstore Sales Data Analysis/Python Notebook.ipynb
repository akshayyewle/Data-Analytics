# %% [markdown]
# # **Setup**

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Data Import**

# %%
df = pd.read_excel('superstore_sales.xlsx')

print(df.shape)
df.head()
# Out:
# (51290, 21)
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %% [markdown]
# # **Data Validation**

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
# ...

# %%
df.describe()
# Out:
#                           order_date                      ship_date  \
# count                          51290                          51290
# mean   2013-05-11 21:26:49.155780864  2013-05-15 20:42:42.745174528
# min              2011-01-01 00:00:00            2011-01-03 00:00:00
# 25%              2012-06-19 00:00:00            2012-06-23 00:00:00
# 50%              2013-07-08 00:00:00            2013-07-12 00:00:00
# 75%              2014-05-22 00:00:00            2014-05-26 00:00:00
# max              2014-12-31 00:00:00            2015-01-07 00:00:00
# std                              NaN                            NaN
#
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.641740      26.375818
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# ...

# %%
df.loc[:,['sales','quantity','discount','profit','shipping_cost']].describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.641740      26.375818
# std      487.565361      2.278766      0.212280    174.424113      57.296810
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000

# %% [markdown]
# # **Data Exploration**

# %%
df.groupby(by='segment')['sales'].agg(['sum','min','max','count'])
# Out:
#                       sum    min       max  count
# segment
# Consumer     6.507949e+06  0.444  13999.96  26518
# Corporate    3.824698e+06  0.556  17499.95  15429
# Home Office  2.309855e+06  0.990  22638.48   9343

# %% [markdown]
# # **Data Analysis**
#
# * Q1. What is the overall sales trend?
# * Q2. Which are the Top 10 products by sales?
# * Q3. Which are the Most Selling Products?
# * Q4. Which is the most preferred Ship Mode?
# * Q5. Which are the Most Profitable Category and Sub-Category?

# %% [markdown]
# ## **Q1. What is the overall sales trend?**

# %%
print(df['order_date'].min())
print(df['order_date'].max())
# Out:
# 2011-01-01 00:00:00
# 2014-12-31 00:00:00

# %%
from time import strftime
df['Order_Month'] = df['order_date'].apply(lambda x: strftime("%Y-%m"))

df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %% [markdown]
# ## **Q2. Which are the Top 10 products by sales?**

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'Order_Month'],
#       dtype='object')

# %%
# Group By Product_id & Get Corresponding Product_Name & sales
df.groupby(['product_id', 'product_name']).agg({'sales':'sum','quantity':'sum'}).sort_values(by='sales', ascending=False).reset_index()
# Out:
#              product_id                                       product_name  \
# 0       TEC-CO-10004722              Canon imageCLASS 2200 Advanced Copier
# 1       TEC-PH-10004664                  Nokia Smart Phone, with Caller ID
# 2       OFF-BI-10003527  Fellowes PB500 Electric Punch Plastic Comb Bin...
# 3       TEC-MA-10002412  Cisco TelePresence System EX90 Videoconferenci...
# 4       TEC-PH-10004823                       Nokia Smart Phone, Full Size
# ...                 ...                                                ...
# 10763  OFF-SME-10000258             Smead Removable Labels, 5000 Label Set
# 10764   OFF-BI-10003323                Cardinal Hole Reinforcements, Clear
# 10765   OFF-BI-10003253                           Ibico Index Tab, Economy
# 10766   OFF-EN-10003604                    Jiffy Clasp Envelope, Set of 50
# 10767   OFF-AP-10002203  Eureka Disposable Bags for Sanitaire Vibra Gro...
#
#             sales  quantity
# 0      61599.8240        20
# ...

# %% [markdown]
# ## **Q3. Which are the Most Selling Products?**

# %% [markdown]
# ## **Q4. Which is the most preferred Ship Mode?**

# %% [markdown]
# ## **Q5. Which are the Most Profitable Category and Sub-Category?**
